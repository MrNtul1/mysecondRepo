# %%
import random

def player_guess(x):
    random_number = random.randint(1, x)
    guess = 0
    while guess != random_number:
        guess = int(input(f"Guess a number between 1 and {x}:"))
        if guess < random_number:
            print("Sorry, guess again because your number is too low")
        elif guess < random_number:
            print("Sorry, guess again because your number is too high")
    print("Congradulations! You have guessed the correct number", random_number)
def computer_guess(x):
    low=1
    high = x
    feedback = ""
    while feedback != "c":
        if low != high:
            guess = random.randint(low, high)
        guess = random.randint(low, high)
        feedback = input(f"is {guess} too high(H), too low(L) or correct(c)") 
        if feedback == "H" or feedback =="h":
            high = guess - 1
        if feedback == "L" or feedback == "l":
            low= guess + 1
    print("Congradulations! computer has guessed the correct number", guess)
guesser = input(" who will be guessing player or computer")
x = int(input("what is the max number"))
if guesser == "computer":
    computer_guess(x)
elif guesser == "player":
    player_guess(x)
else:
    print("ERROR!!! Please select from the above options")
# Out:
#  who will be guessing player or computer computer
# what is the max number 5
# is 5 too high(H), too low(L) or correct(c) h
# is 1 too high(H), too low(L) or correct(c) l
# is 3 too high(H), too low(L) or correct(c) c
# Congradulations! computer has guessed the correct number 3
