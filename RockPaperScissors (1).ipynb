# %%
import random

def play():
    user = input("choose 'r' for rock 'p' for paper 's' for scissors ")
    computer = random.choice(['r', 'p', 's'])
     # rules = r eats s, s eats p, p eats r
    if user == computer:
        return 'tie'
    if is_win(user, computer):
        return "You won"
    return "You Lost"
def is_win(player, opponent):
    #if the player wins it will return true
    if (player == 'r' and opponent == 's') or (player == 's' and opponent =='p') or (player == 'p' and opponent == 'r'):
        return True
print(play())
# Out:
# choose 'r' for rock 'p' for paper 's' for scissors  p
# You Lost
